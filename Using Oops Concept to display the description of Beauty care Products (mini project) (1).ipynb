# %%
## Using Oops Concept to display the description of Beauty care Products (mini project)

class beauty_products :
    
    print(""" Welcome to the Beauty site
        
        1.skin_care
        2.hair_care
        3.makeup""")
    a=input('choose the catagory :')                          #choose the catagory after call the functions
                                                               #fun1= face_washes
    class skin_care :                                           #fun2= face-creams
                                                                 #fun3= lotions
        print(""" 
          1.face_washes
          2.face-creams                             
          3.lotions""")                            
                                                    
                                                      
        def fun1 (self) :                              
            print("""
                   1.himalaya_purifying_neem_face_washes
                   2.lotous_herbals
                   3.milk_delights_face_washe """)
            fw=input('enter the product :')
            
            h='himalaya_purifying_neem_face_washes'
            k='lotous_herbals'
            j='milk_delights_face_washe '
            if fw==h :
                print("""
                HIMALAYA Purifying Neem Face Wash  (400 ml)

                Special price
                ₹315----16% off
                
                --------Specifications-----

                Pack of            -1
                Brand             -HIMALAYA
                Model Name        -Purifying Neem
                Quantity          -400 ml
                Ideal For         -Men & Women
                Face Wash Type    -Gel
                Maximum Shelf Left-36 Months
                Applied For       -Anti-acne & Pimples
                Skin Type         -All Skin Types
                Container Type    -Dispenser 
                
        CLICK AND BUY THE PROTUCT
                
                Flikart==shorturl.at/FNOQV
                Amazon==shorturl.at/BORS5   
                meesho==shorturl.at/eoPX2           """)
                
                
                    
            
            elif fw==k :
                print("""
               LOTUS HERBALS WhiteGlow Skin Whitening And Brightening Gel, Face Cream with SPF-25, for all skin types  (40 g)

                 Special price
                 ₹196 --30% off


                 --------Specifications-----


                 Brand              - LOTUS HERBALS
                 Model Name         - WhiteGlow Skin Whitening And Brightening Gel, Face Cream with SPF-25, for all skin types
                 Quantity           - 40 g
                 Maximum Shelf Life - 36 Months
                 Applied For        - Skin Brightening
                 Organic Type       - Synthetic
                 Ideal Usage        - Day
                 Ideal For          - Women
                 Type               - Gel
                 Container Type     - Jars 
                 
         CLICK AND BUY THE PROTUCT
                
                Flikart==shorturl.at/FNOQV
                Amazon==shorturl.at/BORS5   
                meesho==shorturl.at/eoPX2         """)
               
            else :
                print("""
                NIVEA Milk Delights Honey Face Wash  (100 ml)

                Special price
                ₹93---49% off


                --------Specifications-----

                Pack of             -    1
                Brand               -   NIVEA
                Model Name          -  Milk Delights Honey Face Wash
                Quantity            -  100 ml
                Ideal For           -   Women
                Face Wash Type      -   Liquid
                Ingredient Type     -   Non-Organic
                Maximum Shelf Life  -   30 Months
                Applied For         -   Cleansing
                Skin Type           -   Dry Skin
                Country of Origin   -   India  
                
       CLICK AND BUY THE PROTUCT
                
                Flikart==shorturl.at/FNOQV
                Amazon==shorturl.at/BORS5   
                meesho==shorturl.at/eoPX2          """)
            
        def fun2 (self) :
            print("""       1.the_derma_co
              2.lotous_herbals
              3.plum """)
            to=input('choose the product :')
            n='the_derma_co'
            m='lotous_herbals'
            o='plum '
            if to==m :
                print("""
                Lotus Botanicals Ubtan De-Tan Radiance Face Wash  (100 ml)
                
                Special price
                ₹206---25% off
                
                --------Specifications-----

                Pack of            - 1
                Brand              - Lotus Botanicals
                Model Name         -  Ubtan De-Tan Radiance Face Wash
                Quantity           - 100 ml
                Ideal For          -Men & Women
                Face Wash Type     -  Cream
                Ingredient Type    - Natural
                Maximum Shelf Life  -36 Months
                Applied For        - Nourishment & Moisturization
                Skin Type          -All Skin Types
                Container Type     - Tube
                Country of Origin  - India 
                
        CLICK AND BUY THE PROTUCT
                
                Flikart==shorturl.at/FNOQV
                Amazon==shorturl.at/BORS5   
                meesho==shorturl.at/eoPX2         """)
                     
            elif to==o:
                print("""
                Plum Green Tea Pore Cleansing Face Wash  (75 ml)

               Special price
               ₹200---42% off
               
               --------Specifications-----
               

               Pack of            - 1
               Brand              - Plum
               Model Name         -  Green Tea Pore Cleansing
               Quantity           - 75 ml
               Ideal For          - Men & Women
               Face Wash Type     -  Gel
               Maximum Shelf Life -  24 Months
               Applied For        -  Anti-acne & Pimples, Deep Cleansing, Oil Control, Blackhead Remover, Refreshing
               Skin Type          - Oily Skin, Combination Skin, Sensitive Skin, Normal Skin
               Container Type     - Tube
               Country of Origin  - India
               
       CLICK AND BUY THE PROTUCT
                
                Flikart==shorturl.at/FNOQV
                Amazon==shorturl.at/BORS5   
                meesho==shorturl.at/eoPX2          """)
               
            else :
                print("""
                The Derma Co 2% Salicylic Acid Serum for Acne & Acne Marks  (30 ml)

                Special price
                ₹399----20% off
                
                --------Specifications-----

                Brand            -The Derma Co
                Model Name       - 2% Salicylic Acid Serum for Acne & Acne Marks
                Quantity         - 30 ml
                Applied For      - Daily Care
                Organic Type     -  Synthetic
                Ideal Usage      - All Day
                Ideal For        - Women
                Type              - Serum
                Container Type    - Bottle
                Skin Type         -Oily skin
                
        CLICK AND BUY THE PROTUCT
                
                Flikart==shorturl.at/FNOQV
                Amazon==shorturl.at/BORS5   
                meesho==shorturl.at/eoPX2       """)
                
            
        def fun3(self) :
            print("""
              1.lakme
              2.ponds
              3.nivea """)
            lo=input('enter the product :')
            p='lakme'
            s='ponds'
            u='nivea '
            if lo==p :
                print("""
                Lakmé Blush and Glow Kiwi Crush Face Wash  (100 g)

                Special price
                ₹157---30% of
                
                --------Specifications-----

                Pack of             - 1
                Brand               - Lakmé
                Model Name          - Blush and Glow Kiwi Crush
                Quantity            - 100 g
                Ideal For           - Men & Women
                Face Wash Type      - Cream
                Ingredient Type     -Synthetic
                Maximum Shelf Life  -36 Months
                Applied For         -Nourishment & Moisturization, Radiance & Glow, Deep Cleansing
                Skin Type          - All Skin Types 
                
        CLICK AND BUY THE PROTUCT
                
                Flikart==shorturl.at/FNOQV
                Amazon==shorturl.at/BORS5   
                meesho==shorturl.at/eoPX2  """)
                
            elif lo==s :
                print("""
                POND's White Beauty Spot-less Fairness Face Wash  (50 g)

                Special price
                ₹68-----13% off
                
                --------Specifications-----

                Pack of             -1
                Brand               -POND's
                Model Name          -White Beauty Spot-less Fairness
                Quantity            -50 g
                Ideal For           -Women
                Face Wash Type      -Foam
                Ingredient Type     -Synthetic
                Maximum Shelf Life  -24 Months
                Applied For        -Spot Removal, Deep Cleansing
                Skin Type          -All Skin Types
                
        CLICK AND BUY THE PROTUCT
                
                Flikart==shorturl.at/FNOQV
                Amazon==shorturl.at/BORS5   
                meesho==shorturl.at/eoPX2  """)
                
            else :
                print("""
                NIVEA Rose Water Gel Body lotion, 24H hydration, Non-Sticky & fast absorbing,  (75 ml)
                
                Special price
                PRICE   -₹128
                
                --------Specifications-----

                Sales Package               -1 Gel Body Lotion
                Model Name                  -Rose Water Gel Body lotion, 24H hydration, Non-Sticky & fast absorbing,
                Quantity                    -75 ml
                Ideal For                   -Men & Women
                Form                        -Gel
                Application Area            -Body
                Applied For (Face)          -Moisturization & Nourishment
                Applied For (Body)          -Moisturization & Nourishment
                Skin Type                   -All Skin Types
                Maximum Shelf Life          -30 Months
                Container Type              -Bottle
                Instruction                 -Instruction refers to the detailed information about how something should be done or operated.
                Country of Origin          -India
                
        CLICK AND BUY THE PROTUCT
                
                Flikart==shorturl.at/FNOQV
                Amazon==shorturl.at/BORS5   
                meesho==shorturl.at/eoPX2  """)
                
            
    
    
    
    
  
                    
g=beauty_products()
h=g.skin_care()
sc=input('choose the catagory :')  
if sc=='face_washes' :
    h.fun1()
elif sc== 'face-creams':
    h.fun2()
else:
    h.fun3()
